# %% [raw]
# ---
# output-file: 02-density-db.html
# title:
#
# ---

# %% [markdown]
# # Introduction

# %% [markdown]
# Our ingredients are measured in different units, some weight, some volume, and others in various serving quantities. To get to end goal of concentrations, it would be easiest to standardise these all to one particular unit. In our case we want to convert everything to weight in grams, and in order to convert non-weight measurements we need to have the information of the ingredient densities.
#
# This section will be concerned with finding an appropriate density database, and processing it before the joining the ingredients database onto it.

# %% [markdown]
# # Setup

# %%
from pyprojroot import here
root = here()
import sys
sys.path.append(str(root))

# %%
import pandas as pd
import numpy as np

import nltk
import spacy
from spacy.matcher import Matcher
from spacy.util import filter_spans

import json
from itertools import groupby
import re
import string

from tqdm import tqdm
tqdm.pandas()

from ast import literal_eval

from food_database.utils.utils import *
from food_database.utils.parallel import *

import pickle

from nltk.corpus import wordnet

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
pd.set_option('max_colwidth', None)

# %% [markdown]
# # Datasets Research

# %% [markdown]
# There are online volume-weight conversion calculators, which must make use of density table for foods. Since there's no API endpoint that will allow me to scrape all of the data I need to find a database.
#
# ### Primary Examples
#
# The largest online calculator https://www.aqua-calc.com/calculate/food-volume-to-weight claims to just use data from the [USDA Food Database](https://fdc.nal.usda.gov/download-datasets.html). However this database doesn't contain explicit information about density - it would involve another calculation to do this (there's a [paper](https://www.researchgate.net/publication/241098096_Using_database_values_to_determine_food_density) written specifically on this). I have suspicions that it's using some other form of information - one way to prove it is to compare the reference food name formats with eachother.
#
# Another website https://khymos.org/2014/01/23/volume-to-weight-calculator-for-the-kitchen/ has taken data from both http://www.faqs.org/faqs/cooking/faq/ and the USDA Food Database. I'm skeptical about the latter too because the reference names don't seem to match up and it seems to have a much smaller database. Nevertheless, it sources an easy table of the data which I can use to try it out. I think it will not contain all the ingredients required, but we could try to see.

# %% [markdown]
# ### Khymos Database

# %% [markdown]
# We have a simple density table here.

# %%
density_df = pd.read_csv('../data/datasets/density/food_densities_khymos/food_densities_khymos.csv', usecols=['food', 'g/ml'])
density_df
# Out:
#                   food  g/ml
# 0     allspice, ground  0.42
# 1      almonds, ground  0.36
# 2      almonds, sliced  0.39
# 3       almonds, whole  0.66
# 4            anchovies  1.02
# ..                 ...   ...
# 270         wheat germ  0.53
# 271          wild rice  0.61
# 272          wine, red  0.99
# 273        wine, white  0.99
# 274  yeast, active dry  1.23
#
# [275 rows x 2 columns]

# %% [markdown]
# This is a small database which definitely will not have all of our required ingredients.

# %% [markdown]
# ### USDA FoodData Central Database

# %%
food_df = pd.read_csv('../data/datasets/density/FoodData_Central_csv_2023-04-20/food.csv', index_col='fdc_id')
food_portion_df = pd.read_csv('../data/datasets/density/FoodData_Central_csv_2023-04-20/food_portion.csv', index_col=['fdc_id', 'id'])

food_df.shape, food_portion_df.shape
# Out:
# ((1913739, 4), (47837, 9))

# %%
food_df.head()
# Out:
#                  data_type  \
# fdc_id
# 1105904       branded_food
# 1105905       branded_food
# 1105906       branded_food
# 1105907       branded_food
# 1105898  experimental_food
#
#                                                                                                                description  \
# fdc_id
# 1105904                                                                                         WESSON Vegetable Oil 1 GAL
# 1105905                                                                                                 SWANSON BROTH BEEF
# 1105906                                                                           CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 1105907                                                                        CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 1105898  Discrepancy between the Atwater factor predicted and empirically measured energy values of almonds in human diets
#
#          food_category_id publication_date
# fdc_id
# 1105904               NaN       2020-11-13
# 1105905               NaN       2020-11-13
# 1105906               NaN       2020-11-13
# 1105907               NaN       2020-11-13
# 1105898               NaN       2020-10-30

# %%
food_df['description'].fillna('', inplace=True)

# %%
food_df[food_df['description'].str.contains('Pepper, raw')]
# Out:
#                  data_type       description  food_category_id  \
# fdc_id
# 2345319  survey_fndds_food  Pepper, raw, NFS            6420.0
#
#         publication_date
# fdc_id
# 2345319       2022-10-28

# %%
food_portion_df.loc[food_df[food_df['description'].str.contains('Pepper, raw')].iloc[0].name]
# Out:
#         seq_num  amount  measure_unit_id     portion_description modifier  \
# id
# 286043      1.0     NaN             9999                 1 piece    61667
# 286044      2.0     NaN             9999                  1 ring    61820
# 286045      3.0     NaN             9999             1 miniature    61467
# 286046      4.0     NaN             9999               1 regular    62862
# 286047      5.0     NaN             9999                   1 cup    10205
# 286048      6.0     NaN             9999  Quantity not specified    90000
#
#         gram_weight  data_points  footnote  min_year_acquired
# id
# 286043         10.0          NaN       NaN                NaN
# 286044         10.0          NaN       NaN                NaN
# 286045         30.0          NaN       NaN                NaN
# 286046        120.0          NaN       NaN                NaN
# 286047        150.0          NaN       NaN                NaN
# 286048         20.0          NaN       NaN                NaN

# %% [markdown]
# ### Decision

# %% [markdown]
# The USDA will be used as it has undoubtably more foods to find matches for. The vast selection of foods will have its own challenges, so it might be best to try the cleaner Khymos database first. However because we will need to work with the USDA database for the missing foods anyway, we will begin with working with this.

# %% [markdown]
# # USDA Dataset

# %% [markdown]
# This on the other hand is a massive database. It contians far more ingredients than we'd need, which is its own challenge. We will need to try to filter the database as much as possible, setting it up to be able to be searched not only efficiently, but most accurately too.
#
# As well as searching, there is another challenge in that it doesn't provide explicit density information. What it has instead is information of various portions for the food, with a measured gram weight for each. It's simple enough to get the density here, just taking a volumetric poriton measure and converting it to density using its gram weight. What we can also do with this information is actually get the gram weight for other measures too, for example one *whole* pepper, or a coffee serving etc.
#
# This means that we will need to find a way of not only selecting the right food from the `food_df`, but also the right portion from its corresponding `portion_df` entries.

# %% [markdown]
# ## Other Database Fields

# %%
food_category_wwei_df = pd.read_csv('../data/datasets/density/FoodData_Central_csv_2023-04-20/wweia_food_category.csv')
food_category_wwei_df[food_category_wwei_df['wweia_food_category_description'].str.contains("beef")]
# Out:
#     wweia_food_category wweia_food_category_description
# 15                 2004                     Ground beef

# %%
food_portion_df.loc[2341335]
# Out:
#         seq_num  amount  measure_unit_id     portion_description modifier  \
# id
# 270013      1.0     NaN             9999    1 cup, cooked, diced    10049
# 270014      2.0     NaN             9999                 1 piece    61667
# 270015      3.0     NaN             9999                 1 slice    61935
# 270016      4.0     NaN             9999            1 oz, cooked    40040
# 270017     16.0     NaN             9999  Quantity not specified    90000
#
#         gram_weight  data_points  footnote  min_year_acquired
# id
# 270013       135.00          NaN       NaN                NaN
# 270014        60.00          NaN       NaN                NaN
# 270015        60.00          NaN       NaN                NaN
# 270016        28.35          NaN       NaN                NaN
# 270017        85.00          NaN       NaN                NaN

# %%
food_df[food_df['food_category_id'] == 2202].head(20)
# Out:
#                  data_type  \
# fdc_id
# 2341335  survey_fndds_food
# 2341336  survey_fndds_food
# 2341337  survey_fndds_food
# 2341338  survey_fndds_food
# 2341339  survey_fndds_food
# 2341340  survey_fndds_food
# 2341341  survey_fndds_food
# 2341342  survey_fndds_food
# 2341343  survey_fndds_food
# 2341344  survey_fndds_food
# 2341345  survey_fndds_food
# 2341346  survey_fndds_food
# 2341347  survey_fndds_food
# 2341348  survey_fndds_food
# 2341349  survey_fndds_food
# 2341350  survey_fndds_food
# 2341351  survey_fndds_food
# 2341352  survey_fndds_food
# 2341353  survey_fndds_food
# 2341354  survey_fndds_food
#
#                                                                      description  \
# fdc_id
# 2341335           Chicken, NS as to part and cooking method, NS as to skin eaten
# 2341336                    Chicken, NS as to part and cooking method, skin eaten
# 2341337                Chicken, NS as to part and cooking method, skin not eaten
# 2341338  Chicken, NS as to part, baked, broiled, or roasted, NS as to skin eaten
# 2341339           Chicken, NS as to part, baked, broiled, or roasted, skin eaten
# 2341340       Chicken, NS as to part, baked, broiled, or roasted, skin not eaten
# 2341341                  Chicken, NS as to part, rotisserie, NS as to skin eaten
# 2341342                           Chicken, NS as to part, rotisserie, skin eaten
# 2341343                       Chicken, NS as to part, rotisserie, skin not eaten
# 2341344                      Chicken, NS as to part, stewed, NS as to skin eaten
# 2341345                               Chicken, NS as to part, stewed, skin eaten
# 2341346                           Chicken, NS as to part, stewed, skin not eaten
# 2341347       Chicken, NS as to part, grilled without sauce, NS as to skin eaten
# 2341348                Chicken, NS as to part, grilled without sauce, skin eaten
# 2341349            Chicken, NS as to part, grilled without sauce, skin not eaten
# 2341350          Chicken, NS as to part, grilled with sauce, NS as to skin eaten
# 2341351                   Chicken, NS as to part, grilled with sauce, skin eaten
# 2341352               Chicken, NS as to part, grilled with sauce, skin not eaten
# 2341353                              Chicken, NS as to part, sauteed, skin eaten
# 2341354                          Chicken, NS as to part, sauteed, skin not eaten
#
#          food_category_id publication_date
# fdc_id
# 2341335            2202.0       2022-10-28
# 2341336            2202.0       2022-10-28
# 2341337            2202.0       2022-10-28
# 2341338            2202.0       2022-10-28
# 2341339            2202.0       2022-10-28
# 2341340            2202.0       2022-10-28
# 2341341            2202.0       2022-10-28
# 2341342            2202.0       2022-10-28
# 2341343            2202.0       2022-10-28
# 2341344            2202.0       2022-10-28
# 2341345            2202.0       2022-10-28
# 2341346            2202.0       2022-10-28
# 2341347            2202.0       2022-10-28
# 2341348            2202.0       2022-10-28
# 2341349            2202.0       2022-10-28
# 2341350            2202.0       2022-10-28
# 2341351            2202.0       2022-10-28
# 2341352            2202.0       2022-10-28
# 2341353            2202.0       2022-10-28
# 2341354            2202.0       2022-10-28

# %% [markdown]
# ### Food Category

# %% [markdown]
# Just an idea that we could use the food category to help with the reference.

# %% [markdown]
# # Processing Food DF

# %%
food_df_full = food_df.copy(deep=True)

# %% [markdown]
# ## Dtypes

# %%
food_df = food_df.convert_dtypes()
food_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1913739 entries, 1105904 to 2554914
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   data_type         string
#  1   description       string
#  2   food_category_id  Int64
#  3   publication_date  string
# dtypes: Int64(1), string(3)
# memory usage: 74.8 MB

# %% [markdown]
# ## LLematization

# %% [markdown]
# Getting just the base of the appropriate word.

# %% [markdown]
# ## Filtering Ingredients

# %% [markdown]
# We are only interested in raw, whole foods, for which we will try filter down the section to get there.

# %% [markdown]
# ### Food `data_type`

# %% [markdown]
# Many of the unnecessary non-whole ingredients can be filtered out through their data_type category.

# %%
food_df.value_counts('data_type')
# Out:
# data_type
# branded_food                1845297
# sub_sample_food               44537
# sr_legacy_food                 7793
# market_acquistion              6402
# survey_fndds_food              5624
# sample_food                    2904
# agricultural_acquisition        810
# foundation_food                 307
# experimental_food                65
# Name: count, dtype: int64

# %%
food_df = food_df[~food_df['data_type'].str.strip().isin(['branded_food','sub_sample_food', 'market_acquistion', 'agricultural_acquisition'])]
food_df.shape
# Out:
# (16693, 4)

# %%
# ordering catgegories according to importance (to aid with searching)
food_df['data_type'] = pd.Categorical(food_df['data_type'], categories=['foundation_food', 'survey_fndds_food', 'sr_legacy_food'], ordered=True)

# %% [markdown]
# ## Syncing Food DF & Portion DF Entries

# %% [markdown]
# Only the foods with entries in the portion DF will be of use.

# %%
food_df = food_df[food_df.index.isin(food_portion_df.reset_index(1).index.unique())]

# %%
food_portion_df = food_portion_df[food_portion_df.index.get_level_values(0).isin(food_df.index.unique())]

# %% [markdown]
# ## NA's

# %%
food_df = food_df[~food_df['description'].isnull()]

# %% [markdown]
# ## Parsing Food Descriptions

# %% [markdown]
# Ingredient names come in the form of a 'description', which is a comma separated string contianing the ingredient name as well as other descriptions about the specifict type. These orderings depend on the study that was done ie. the `data_type`. These specificies can can often be ignored, as we want to be dealing with the fundamental ingredient (ie. raw) in the dataset. However there are factors that should be considered (eg. eggs whole/yolk/white, specific part of meat, dried ingredients, type of flour).
#
# To help work with the data, we parse each one of these into a list of descriptions.

# %%
food_df['description']
# Out:
# fdc_id
# 167512     Pillsbury Golden Layer Buttermilk Biscuits, Artificial Flavor, refrigerated dough
# 167513                              Pillsbury, Cinnamon Rolls with Icing, refrigerated dough
# 167514                      Kraft Foods, Shake N Bake Original Recipe, Coating for Pork, dry
# 167515                                        George Weston Bakeries, Thomas English Muffins
# 167516                                            Waffles, buttermilk, frozen, ready-to-heat
#                                                  ...
# 2346351                                            Sports drink, low calorie (Powerade Zero)
# 2346352                                                            Sports drink, low calorie
# 2346353                                              Fluid replacement, electrolyte solution
# 2346354                                               Fluid replacement, 5% glucose in water
# 2346355                                                              Fruit juice, acai blend
# Name: description, Length: 13245, dtype: string

# %%
food_df['description_list'] = food_df['description'].apply(lambda description: description.split(', '))

# %% [markdown]
# ## Filtering

# %%
food_df[food_df['description'].str.lower().str.contains('flour') & food_df['description'].str.lower().str.contains('wheat')]
# Out:
#              data_type  \
# fdc_id
# 167938  sr_legacy_food
# 168869  sr_legacy_food
# 168893  sr_legacy_food
# 168894  sr_legacy_food
# 168895  sr_legacy_food
# 168896  sr_legacy_food
# 168913  sr_legacy_food
# 168924  sr_legacy_food
# 168936  sr_legacy_food
# 169723  sr_legacy_food
# 169724  sr_legacy_food
# 169754  sr_legacy_food
# 169761  sr_legacy_food
# 170687  sr_legacy_food
#
#                                                                                                 description  \
# fdc_id
# 167938  Pan Dulce, La Ricura, Salpora de Arroz con Azucar, cookie-like, contains wheat flour and rice flour
# 168869                              Cornmeal, yellow, self-rising, bolted, with wheat flour added, enriched
# 168893                       Wheat flour, whole-grain (Includes foods for USDA's Food Distribution Program)
# 168894                                                  Wheat flour, white, all-purpose, enriched, bleached
# 168895                                               Wheat flour, white, all-purpose, self-rising, enriched
# 168896                                                                  Wheat flour, white, bread, enriched
# 168913                                                                      Wheat flours, bread, unenriched
# 168924                               Cornmeal, white, self-rising, bolted, with wheat flour added, enriched
# 168936                                                Wheat flour, white, all-purpose, enriched, unbleached
# 169723                                                                   Wheat flour, white, cake, enriched
# 169724                                                           Wheat flour, white, tortilla mix, enriched
# 169754                                         Wheat flour, white, all-purpose, enriched, calcium-fortified
# 169761                                                          Wheat flour, white, all-purpose, unenriched
# 170687                                                                         Buckwheat flour, whole-groat
#
#         food_category_id publication_date  \
# fdc_id
# 167938              <NA>       2019-04-01
# 168869              <NA>       2019-04-01
# 168893              <NA>       2019-04-01
# 168894              <NA>       2019-04-01
# 168895              <NA>       2019-04-01
# 168896              <NA>       2019-04-01
# 168913              <NA>       2019-04-01
# 168924              <NA>       2019-04-01
# 168936              <NA>       2019-04-01
# 169723              <NA>       2019-04-01
# 169724              <NA>       2019-04-01
# 169754              <NA>       2019-04-01
# 169761              <NA>       2019-04-01
# 170687              <NA>       2019-04-01
#
#                                                                                              description_list
# fdc_id
# 167938  [Pan Dulce, La Ricura, Salpora de Arroz con Azucar, cookie-like, contains wheat flour and rice flour]
# 168869                              [Cornmeal, yellow, self-rising, bolted, with wheat flour added, enriched]
# 168893                       [Wheat flour, whole-grain (Includes foods for USDA's Food Distribution Program)]
# 168894                                                  [Wheat flour, white, all-purpose, enriched, bleached]
# 168895                                               [Wheat flour, white, all-purpose, self-rising, enriched]
# 168896                                                                  [Wheat flour, white, bread, enriched]
# 168913                                                                      [Wheat flours, bread, unenriched]
# 168924                               [Cornmeal, white, self-rising, bolted, with wheat flour added, enriched]
# 168936                                                [Wheat flour, white, all-purpose, enriched, unbleached]
# 169723                                                                   [Wheat flour, white, cake, enriched]
# 169724                                                           [Wheat flour, white, tortilla mix, enriched]
# 169754                                         [Wheat flour, white, all-purpose, enriched, calcium-fortified]
# 169761                                                          [Wheat flour, white, all-purpose, unenriched]
# 170687                                                                         [Buckwheat flour, whole-groat]

# %%
food_df.query(f'description.str.lower().str.contains("mango")')
# Out:
#                  data_type  \
# fdc_id
# 167785      sr_legacy_food
# 167795      sr_legacy_food
# 169090      sr_legacy_food
# 169910      sr_legacy_food
# 171341      sr_legacy_food
# 171933      sr_legacy_food
# 172254      sr_legacy_food
# 173173      sr_legacy_food
# 173186      sr_legacy_food
# 174165      sr_legacy_food
# 2344700  survey_fndds_food
# 2344737  survey_fndds_food
# 2344738  survey_fndds_food
# 2344739  survey_fndds_food
# 2344839  survey_fndds_food
# 2344866  survey_fndds_food
#
#                                                                 description  \
# fdc_id
# 167785                                                 Mango nectar, canned
# 167795                      Fruit juice smoothie, NAKED JUICE, MIGHTY MANGO
# 169090                                       Mangosteen, canned, syrup pack
# 169910                                                          Mangos, raw
# 171341                          Babyfood, fruit dessert, mango with tapioca
# 171933                           Beverages, V8 V-FUSION Juices, Peach Mango
# 172254                   Babyfood, GERBER, 3rd Foods, apple, mango and kiwi
# 173173   Beverages, FUZE, orange mango, fortified with vitamins A, C, E, B6
# 173186                          Beverages, V8 SPLASH Smoothies, Peach Mango
# 174165                       Beverages, V8 SPLASH Juice Drinks, Mango Peach
# 2344700                                                        Mango, dried
# 2344737                                                          Mango, raw
# 2344738                                                       Mango, canned
# 2344739                                                       Mango, frozen
# 2344839                                                        Mango nectar
# 2344866                                                Baby Toddler mangoes
#
#          food_category_id publication_date  \
# fdc_id
# 167785               <NA>       2019-04-01
# 167795               <NA>       2019-04-01
# 169090               <NA>       2019-04-01
# 169910               <NA>       2019-04-01
# 171341               <NA>       2019-04-01
# 171933               <NA>       2019-04-01
# 172254               <NA>       2019-04-01
# 173173               <NA>       2019-04-01
# 173186               <NA>       2019-04-01
# 174165               <NA>       2019-04-01
# 2344700              6016       2022-10-28
# 2344737              6024       2022-10-28
# 2344738              6024       2022-10-28
# 2344739              6024       2022-10-28
# 2344839              7204       2022-10-28
# 2344866              9004       2022-10-28
#
#                                                              description_list
# fdc_id
# 167785                                                 [Mango nectar, canned]
# 167795                      [Fruit juice smoothie, NAKED JUICE, MIGHTY MANGO]
# 169090                                       [Mangosteen, canned, syrup pack]
# 169910                                                          [Mangos, raw]
# 171341                          [Babyfood, fruit dessert, mango with tapioca]
# 171933                           [Beverages, V8 V-FUSION Juices, Peach Mango]
# 172254                   [Babyfood, GERBER, 3rd Foods, apple, mango and kiwi]
# 173173   [Beverages, FUZE, orange mango, fortified with vitamins A, C, E, B6]
# 173186                          [Beverages, V8 SPLASH Smoothies, Peach Mango]
# 174165                       [Beverages, V8 SPLASH Juice Drinks, Mango Peach]
# 2344700                                                        [Mango, dried]
# 2344737                                                          [Mango, raw]
# 2344738                                                       [Mango, canned]
# 2344739                                                       [Mango, frozen]
# 2344839                                                        [Mango nectar]
# 2344866                                                [Baby Toddler mangoes]

# %% [markdown]
# ### Filtering Brands/Meals

# %% [markdown]
# We want to avoid brand names / full meals showing up in the food_df.
#
# There's a number of ways of doing this, the following section will investigate these:

# %%
food_df[food_df['description'].str.contains('flour') & food_df['description'].str.contains('wheat')]
# Out:
#              data_type  \
# fdc_id
# 167938  sr_legacy_food
# 168869  sr_legacy_food
# 168924  sr_legacy_food
# 170687  sr_legacy_food
#
#                                                                                                 description  \
# fdc_id
# 167938  Pan Dulce, La Ricura, Salpora de Arroz con Azucar, cookie-like, contains wheat flour and rice flour
# 168869                              Cornmeal, yellow, self-rising, bolted, with wheat flour added, enriched
# 168924                               Cornmeal, white, self-rising, bolted, with wheat flour added, enriched
# 170687                                                                         Buckwheat flour, whole-groat
#
#         food_category_id publication_date  \
# fdc_id
# 167938              <NA>       2019-04-01
# 168869              <NA>       2019-04-01
# 168924              <NA>       2019-04-01
# 170687              <NA>       2019-04-01
#
#                                                                                              description_list
# fdc_id
# 167938  [Pan Dulce, La Ricura, Salpora de Arroz con Azucar, cookie-like, contains wheat flour and rice flour]
# 168869                              [Cornmeal, yellow, self-rising, bolted, with wheat flour added, enriched]
# 168924                               [Cornmeal, white, self-rising, bolted, with wheat flour added, enriched]
# 170687                                                                         [Buckwheat flour, whole-groat]

# %%
food_df
# Out:
#                  data_type  \
# fdc_id
# 167512      sr_legacy_food
# 167513      sr_legacy_food
# 167514      sr_legacy_food
# 167515      sr_legacy_food
# 167516      sr_legacy_food
# ...                    ...
# 2346351  survey_fndds_food
# 2346352  survey_fndds_food
# 2346353  survey_fndds_food
# 2346354  survey_fndds_food
# 2346355  survey_fndds_food
#
#                                                                                description  \
# fdc_id
# 167512   Pillsbury Golden Layer Buttermilk Biscuits, Artificial Flavor, refrigerated dough
# 167513                            Pillsbury, Cinnamon Rolls with Icing, refrigerated dough
# 167514                    Kraft Foods, Shake N Bake Original Recipe, Coating for Pork, dry
# 167515                                      George Weston Bakeries, Thomas English Muffins
# 167516                                          Waffles, buttermilk, frozen, ready-to-heat
# ...                                                                                    ...
# 2346351                                          Sports drink, low calorie (Powerade Zero)
# 2346352                                                          Sports drink, low calorie
# 2346353                                            Fluid replacement, electrolyte solution
# 2346354                                             Fluid replacement, 5% glucose in water
# 2346355                                                            Fruit juice, acai blend
#
#          food_category_id publication_date  \
# fdc_id
# 167512               <NA>       2019-04-01
# 167513               <NA>       2019-04-01
# 167514               <NA>       2019-04-01
# 167515               <NA>       2019-04-01
# 167516               <NA>       2019-04-01
# ...                   ...              ...
# 2346351              7104       2022-10-28
# 2346352              7104       2022-10-28
# 2346353              7206       2022-10-28
# 2346354              7206       2022-10-28
# 2346355              7204       2022-10-28
#
#                                                                             description_list
# fdc_id
# 167512   [Pillsbury Golden Layer Buttermilk Biscuits, Artificial Flavor, refrigerated dough]
# 167513                            [Pillsbury, Cinnamon Rolls with Icing, refrigerated dough]
# 167514                    [Kraft Foods, Shake N Bake Original Recipe, Coating for Pork, dry]
# 167515                                      [George Weston Bakeries, Thomas English Muffins]
# 167516                                          [Waffles, buttermilk, frozen, ready-to-heat]
# ...                                                                                      ...
# 2346351                                          [Sports drink, low calorie (Powerade Zero)]
# 2346352                                                          [Sports drink, low calorie]
# 2346353                                            [Fluid replacement, electrolyte solution]
# 2346354                                             [Fluid replacement, 5% glucose in water]
# 2346355                                                            [Fruit juice, acai blend]
#
# [13245 rows x 5 columns]

# %%
food_df['description'][food_df['description'].str.contains('with')]
# Out:
# fdc_id
# 167513                   Pillsbury, Cinnamon Rolls with Icing, refrigerated dough
# 167523            Pie crust, deep dish, frozen, unbaked, made with enriched flour
# 167546                                  Candies, honey-combed, with peanut butter
# 167551                              Snacks, popcorn, caramel-coated, with peanuts
# 167552                           Snacks, popcorn, caramel-coated, without peanuts
#                                             ...
# 2346180                                               Oatmeal beverage with water
# 2346181                                                Oatmeal beverage with milk
# 2346184                                     Cornmeal beverage with chocolate milk
# 2346188    Fruit flavored drink, with high vitamin C, powdered, not reconstituted
# 2346257                                                        Liqueur with cream
# Name: description, Length: 3125, dtype: string

# %% [markdown]
# Often times these appear in lengthy phrases.

# %%
def filter_long_phrases(food_description):
    # note: exluding bracketed text as this is sometimes important
    if any([len(re.sub(r'\([^)]*\)', '', phrase)) > 30 for phrase in food_description.split(',')]):
        return True
    return False
    
food_df[food_df['description'].apply(filter_long_phrases)]
# Out:
#                  data_type  \
# fdc_id
# 167512      sr_legacy_food
# 167531      sr_legacy_food
# 167548      sr_legacy_food
# 167581      sr_legacy_food
# 167583      sr_legacy_food
# ...                    ...
# 2346140  survey_fndds_food
# 2346155  survey_fndds_food
# 2346168  survey_fndds_food
# 2346169  survey_fndds_food
# 2346184  survey_fndds_food
#
#                                                                                description  \
# fdc_id
# 167512   Pillsbury Golden Layer Buttermilk Biscuits, Artificial Flavor, refrigerated dough
# 167531                                    Crackers, cream, La Moderna Rikis Cream Crackers
# 167548              Snacks, granola bars, soft, uncoated, peanut butter and chocolate chip
# 167581                                  Candies, NESTLE, GOOBERS Chocolate Covered Peanuts
# 167583                                          Candies, TWIZZLERS Strawberry Twists Candy
# ...                                                                                    ...
# 2346140                                        Fruit punch, made with fruit juice and soda
# 2346155                               Vegetable and fruit juice drink, with high vitamin C
# 2346168                         Vegetable and fruit juice drink, with high vitamin C, diet
# 2346169                        Vegetable and fruit juice drink, with high vitamin C, light
# 2346184                                              Cornmeal beverage with chocolate milk
#
#          food_category_id publication_date  \
# fdc_id
# 167512               <NA>       2019-04-01
# 167531               <NA>       2019-04-01
# 167548               <NA>       2019-04-01
# 167581               <NA>       2019-04-01
# 167583               <NA>       2019-04-01
# ...                   ...              ...
# 2346140              7204       2022-10-28
# 2346155              7204       2022-10-28
# 2346168              7106       2022-10-28
# 2346169              7204       2022-10-28
# 2346184              7220       2022-10-28
#
#                                                                             description_list
# fdc_id
# 167512   [Pillsbury Golden Layer Buttermilk Biscuits, Artificial Flavor, refrigerated dough]
# 167531                                    [Crackers, cream, La Moderna Rikis Cream Crackers]
# 167548              [Snacks, granola bars, soft, uncoated, peanut butter and chocolate chip]
# 167581                                  [Candies, NESTLE, GOOBERS Chocolate Covered Peanuts]
# 167583                                          [Candies, TWIZZLERS Strawberry Twists Candy]
# ...                                                                                      ...
# 2346140                                        [Fruit punch, made with fruit juice and soda]
# 2346155                               [Vegetable and fruit juice drink, with high vitamin C]
# 2346168                         [Vegetable and fruit juice drink, with high vitamin C, diet]
# 2346169                        [Vegetable and fruit juice drink, with high vitamin C, light]
# 2346184                                              [Cornmeal beverage with chocolate milk]
#
# [1315 rows x 5 columns]

# %%
food_df = food_df[~food_df['description'].apply(filter_long_phrases)]
food_df.shape
# Out:
# (11930, 5)

# %% [markdown]
# Foods containing 'with' are the majority of othe time bloated and too specific.

# %%
food_df[food_df['description'].str.contains('with')]
# Out:
#                  data_type  \
# fdc_id
# 167513      sr_legacy_food
# 167523      sr_legacy_food
# 167546      sr_legacy_food
# 167551      sr_legacy_food
# 167552      sr_legacy_food
# ...                    ...
# 2346179  survey_fndds_food
# 2346180  survey_fndds_food
# 2346181  survey_fndds_food
# 2346188  survey_fndds_food
# 2346257  survey_fndds_food
#
#                                                                     description  \
# fdc_id
# 167513                 Pillsbury, Cinnamon Rolls with Icing, refrigerated dough
# 167523          Pie crust, deep dish, frozen, unbaked, made with enriched flour
# 167546                                Candies, honey-combed, with peanut butter
# 167551                            Snacks, popcorn, caramel-coated, with peanuts
# 167552                         Snacks, popcorn, caramel-coated, without peanuts
# ...                                                                         ...
# 2346179                                       Horchata beverage, made with milk
# 2346180                                             Oatmeal beverage with water
# 2346181                                              Oatmeal beverage with milk
# 2346188  Fruit flavored drink, with high vitamin C, powdered, not reconstituted
# 2346257                                                      Liqueur with cream
#
#          food_category_id publication_date  \
# fdc_id
# 167513               <NA>       2019-04-01
# 167523               <NA>       2019-04-01
# 167546               <NA>       2019-04-01
# 167551               <NA>       2019-04-01
# 167552               <NA>       2019-04-01
# ...                   ...              ...
# 2346179              7220       2022-10-28
# 2346180              7220       2022-10-28
# 2346181              7220       2022-10-28
# 2346188              9999       2022-10-28
# 2346257              7506       2022-10-28
#
#                                                                  description_list
# fdc_id
# 167513                 [Pillsbury, Cinnamon Rolls with Icing, refrigerated dough]
# 167523          [Pie crust, deep dish, frozen, unbaked, made with enriched flour]
# 167546                                [Candies, honey-combed, with peanut butter]
# 167551                            [Snacks, popcorn, caramel-coated, with peanuts]
# 167552                         [Snacks, popcorn, caramel-coated, without peanuts]
# ...                                                                           ...
# 2346179                                       [Horchata beverage, made with milk]
# 2346180                                             [Oatmeal beverage with water]
# 2346181                                              [Oatmeal beverage with milk]
# 2346188  [Fruit flavored drink, with high vitamin C, powdered, not reconstituted]
# 2346257                                                      [Liqueur with cream]
#
# [2329 rows x 5 columns]

# %%
food_df = food_df[~food_df['description'].str.contains('with')]
food_df.shape
# Out:
# (9601, 5)

# %%
food_df.loc[171474]
# Out:
# data_type                                                      sr_legacy_food
# description           Chicken, broilers or fryers, breast, meat and skin, raw
# food_category_id                                                         <NA>
# publication_date                                                   2019-04-01
# description_list    [Chicken, broilers or fryers, breast, meat and skin, raw]
# Name: 171474, dtype: object

# %% [markdown]
# Brands are often written as fully capitized words.

# %%
food_df[food_df['description'].apply(lambda x: bool(re.search(r'\b[A-Z0-9]{2,}\b', x)))]
# Out:
#                  data_type                                description  \
# fdc_id
# 167562      sr_legacy_food              Candies, ALMOND JOY Candy Bar
# 167563      sr_legacy_food            Candies, TWIZZLERS CHERRY BITES
# 167564      sr_legacy_food  Candies, NESTLE, BIT-O'-HONEY Candy Chews
# 167565      sr_legacy_food          Candies, NESTLE, BUTTERFINGER Bar
# 167582      sr_legacy_food             Candies, NESTLE, BABY RUTH Bar
# ...                    ...                                        ...
# 2346339  survey_fndds_food             Energy drink, sugar-free (NOS)
# 2346344  survey_fndds_food                          Energy drink (XS)
# 2346345  survey_fndds_food                Energy drink (XS Gold Plus)
# 2346349  survey_fndds_food                          Sports drink, NFS
# 2346350  survey_fndds_food    Sports drink, low calorie (Gatorade G2)
#
#          food_category_id publication_date  \
# fdc_id
# 167562               <NA>       2019-04-01
# 167563               <NA>       2019-04-01
# 167564               <NA>       2019-04-01
# 167565               <NA>       2019-04-01
# 167582               <NA>       2019-04-01
# ...                   ...              ...
# 2346339              7104       2022-10-28
# 2346344              7206       2022-10-28
# 2346345              7206       2022-10-28
# 2346349              7206       2022-10-28
# 2346350              7104       2022-10-28
#
#                                     description_list
# fdc_id
# 167562               [Candies, ALMOND JOY Candy Bar]
# 167563             [Candies, TWIZZLERS CHERRY BITES]
# 167564   [Candies, NESTLE, BIT-O'-HONEY Candy Chews]
# 167565           [Candies, NESTLE, BUTTERFINGER Bar]
# 167582              [Candies, NESTLE, BABY RUTH Bar]
# ...                                              ...
# 2346339             [Energy drink, sugar-free (NOS)]
# 2346344                          [Energy drink (XS)]
# 2346345                [Energy drink (XS Gold Plus)]
# 2346349                          [Sports drink, NFS]
# 2346350    [Sports drink, low calorie (Gatorade G2)]
#
# [1289 rows x 5 columns]

# %% [markdown]
# However we want to make sure this isn't including any useful upper-cased words. One such frequent example is NFS (Not Further Specified). Let's see which are the most common:

# %%
def get_re_match(search_string, regex):
    match = re.search(regex, search_string)
    if match: return search_string[match.start():match.end()]

# %%
_ = food_df['description'].apply(get_re_match, args=(r'\b[A-Z0-9]{2,}\b',))
_ = _[_.notnull()]
_.value_counts().head(10)
# Out:
# description
# NFS       245
# NS        177
# QUAKER     54
# USDA       51
# 100        39
# 10         32
# SILK       27
# MARS       26
# MALT       24
# V8         20
# Name: count, dtype: int64

# %%
food_df[food_df['description'].str.contains("USDA")].head()
# Out:
#              data_type  \
# fdc_id
# 167776  sr_legacy_food
# 167778  sr_legacy_food
# 167779  sr_legacy_food
# 167816  sr_legacy_food
# 168165  sr_legacy_food
#
#                                                                                                               description  \
# fdc_id
# 167776                                         Pears, raw, bartlett (Includes foods for USDA's Food Distribution Program)
# 167778                                             Pears, raw, bosc (Includes foods for USDA's Food Distribution Program)
# 167779                                      Pears, raw, green anjou (Includes foods for USDA's Food Distribution Program)
# 167816  Pork, fresh, leg (ham), rump half, separable lean only, raw (Includes foods for USDA's Food Distribution Program)
# 168165                                      Raisins, dark, seedless (Includes foods for USDA's Food Distribution Program)
#
#         food_category_id publication_date  \
# fdc_id
# 167776              <NA>       2019-04-01
# 167778              <NA>       2019-04-01
# 167779              <NA>       2019-04-01
# 167816              <NA>       2019-04-01
# 168165              <NA>       2019-04-01
#
#                                                                                                            description_list
# fdc_id
# 167776                                         [Pears, raw, bartlett (Includes foods for USDA's Food Distribution Program)]
# 167778                                             [Pears, raw, bosc (Includes foods for USDA's Food Distribution Program)]
# 167779                                      [Pears, raw, green anjou (Includes foods for USDA's Food Distribution Program)]
# 167816  [Pork, fresh, leg (ham), rump half, separable lean only, raw (Includes foods for USDA's Food Distribution Program)]
# 168165                                      [Raisins, dark, seedless (Includes foods for USDA's Food Distribution Program)]

# %%
food_df['description'] = food_df['description'].apply(lambda x: x.replace(" (Includes foods for USDA's Food Distribution Program)", ""))

# %%
food_df = food_df[~(food_df['description'].apply(lambda x: bool(re.search(r'\b[A-Z0-9]{2,}\b', x))) & ~(food_df['description'].str.contains('NFS')) & ~(food_df['description'].str.contains('NS')))]

# %% [markdown]
# What about series of capitalised words

# %%
food_df[food_df['description'].apply(lambda x: bool(re.search(r'([A-Z][a-z]+(?=\s[A-Z])(?:\s[A-Z][a-z]+)+)', x)))]
# Out:
#                  data_type  \
# fdc_id
# 167514      sr_legacy_food
# 167515      sr_legacy_food
# 167520      sr_legacy_food
# 167521      sr_legacy_food
# 167522      sr_legacy_food
# ...                    ...
# 2346334  survey_fndds_food
# 2346338  survey_fndds_food
# 2346340  survey_fndds_food
# 2346341  survey_fndds_food
# 2346351  survey_fndds_food
#
#                                                               description  \
# fdc_id
# 167514   Kraft Foods, Shake N Bake Original Recipe, Coating for Pork, dry
# 167515                     George Weston Bakeries, Thomas English Muffins
# 167520                Pie Crust, Cookie-type, Graham Cracker, Ready Crust
# 167521                     Pie Crust, Cookie-type, Chocolate, Ready Crust
# 167522                            Pie, Dutch Apple, Commercially Prepared
# ...                                                                   ...
# 2346334                                                      Energy Drink
# 2346338                                Energy drink, sugar free (No Fear)
# 2346340                Energy drink (Ocean Spray Cran-Energy Juice Drink)
# 2346341                               Energy drink, sugar-free (Red Bull)
# 2346351                         Sports drink, low calorie (Powerade Zero)
#
#          food_category_id publication_date  \
# fdc_id
# 167514               <NA>       2019-04-01
# 167515               <NA>       2019-04-01
# 167520               <NA>       2019-04-01
# 167521               <NA>       2019-04-01
# 167522               <NA>       2019-04-01
# ...                   ...              ...
# 2346334              7206       2022-10-28
# 2346338              7104       2022-10-28
# 2346340              7206       2022-10-28
# 2346341              7104       2022-10-28
# 2346351              7104       2022-10-28
#
#                                                            description_list
# fdc_id
# 167514   [Kraft Foods, Shake N Bake Original Recipe, Coating for Pork, dry]
# 167515                     [George Weston Bakeries, Thomas English Muffins]
# 167520                [Pie Crust, Cookie-type, Graham Cracker, Ready Crust]
# 167521                     [Pie Crust, Cookie-type, Chocolate, Ready Crust]
# 167522                            [Pie, Dutch Apple, Commercially Prepared]
# ...                                                                     ...
# 2346334                                                      [Energy Drink]
# 2346338                                [Energy drink, sugar free (No Fear)]
# 2346340                [Energy drink (Ocean Spray Cran-Energy Juice Drink)]
# 2346341                               [Energy drink, sugar-free (Red Bull)]
# 2346351                         [Sports drink, low calorie (Powerade Zero)]
#
# [612 rows x 5 columns]

# %% [markdown]
# Although not as convincing, it does seem like these are all branded foods that aren't useful to us.

# %%
food_df = food_df[~food_df['description'].apply(lambda x: bool(re.search(r'([A-Z][a-z]+(?=\s[A-Z])(?:\s[A-Z][a-z]+)+)', x)))]

# %%
food_df.shape
# Out:
# (8191, 5)

# %% [markdown]
# ### Filtering "no"s
#
# We don't want values specifically specifying that they don't contain a search term coming up during the search

# %%
def filter_nos(description_list):
    description_list = [description for description in description_list
     if not bool(re.search(r'^no\b', description))]
    return description_list

# %%
assert filter_nos(['sloppy joe', 'no bun']) == ['sloppy joe']

# %%
food_df['description_list'] = food_df['description_list'].apply(filter_nos)

# %%
food_df.loc[2341797]
# Out:
# data_type            survey_fndds_food
# description         Sloppy joe, no bun
# food_category_id                  3002
# publication_date            2022-10-28
# description_list          [Sloppy joe]
# Name: 2341797, dtype: object

# %% [markdown]
# ## Cleaning

# %%
food_df['description_list'] = food_df['description_list'].apply(lambda description_list: [clean_ingredient_string(x) for x in description_list])

# %%
food_df.loc[2341797]
# Out:
# data_type            survey_fndds_food
# description         Sloppy joe, no bun
# food_category_id                  3002
# publication_date            2022-10-28
# description_list          [sloppy joe]
# Name: 2341797, dtype: object

# %% [markdown]
# ## Column Aggregations

# %% [markdown]
# Here we are adding columns that are useful for the joining process.

# %%
food_df['description_length'] = food_df['description'].apply(len)
food_df['description_list_length'] = food_df['description_list'].apply(len)
food_df = food_df[food_df['description_list_length'] != 1] # remove ingredients which do not follow the comma separated format (found that these are not useful).
food_df.head()
# Out:
#              data_type                                            description  \
# fdc_id
# 167516  sr_legacy_food             Waffles, buttermilk, frozen, ready-to-heat
# 167517  sr_legacy_food     Waffle, buttermilk, frozen, ready-to-heat, toasted
# 167518  sr_legacy_food  Waffle, buttermilk, frozen, ready-to-heat, microwaved
# 167519  sr_legacy_food        Waffle, plain, frozen, ready-to-heat, microwave
# 167524  sr_legacy_food         Waffles, chocolate chip, frozen, ready-to-heat
#
#         food_category_id publication_date  \
# fdc_id
# 167516              <NA>       2019-04-01
# 167517              <NA>       2019-04-01
# 167518              <NA>       2019-04-01
# 167519              <NA>       2019-04-01
# 167524              <NA>       2019-04-01
#
#                                                description_list  \
# fdc_id
# 167516              [waffle, buttermilk, frozen, ready-to-heat]
# 167517     [waffle, buttermilk, frozen, ready-to-heat, toasted]
# 167518  [waffle, buttermilk, frozen, ready-to-heat, microwaved]
# 167519        [waffle, plain, frozen, ready-to-heat, microwave]
# 167524          [waffle, chocolate chip, frozen, ready-to-heat]
#
#         description_length  description_list_length
# fdc_id
# 167516                  42                        4
# 167517                  50                        5
# 167518                  53                        5
# 167519                  47                        5
# 167524                  46                        4

# %%
with open('../data/globals/default_words.json', 'r') as f: 
    default_words = json.load(f)['density']

with open('../data/globals/exclusion_words.json', 'r') as f: 
    exclusion_words = json.load(f)['density']

food_df['default_word_count'] = food_df['description_list'].apply(count_list_matches, args=(default_words,))
food_df['exclusion_word_count'] = food_df['description_list'].apply(count_list_matches, args=(exclusion_words,))

# %% [markdown]
# ## Syncing Food DF & Portion DF Entries

# %% [markdown]
# Only the foods with entries in the portion DF will be of use.

# %%
food_df = food_df[food_df.index.isin(food_portion_df.reset_index(1).index.unique())]

# %%
food_portion_df = food_portion_df[food_portion_df.index.get_level_values(0).isin(food_df.index.unique())]

# %% [markdown]
# # Processing Food Portions DF

# %% [markdown]
# ## Dtypes

# %%
food_portion_df = food_portion_df.convert_dtypes()
food_portion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 22521 entries, (167516, 81553) to (2346355, 290505)
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   seq_num              22521 non-null  Int64
#  1   amount               9758 non-null   Float64
#  2   measure_unit_id      22521 non-null  Int64
#  3   portion_description  12764 non-null  string
#  4   modifier             22452 non-null  string
#  5   gram_weight          22521 non-null  Float64
#  6   data_points          2151 non-null   Int64
#  7   footnote             0 non-null      Int64
#  8   min_year_acquired    159 non-null    Int64
# dtypes: Float64(2), Int64(5), string(2)
# memory usage: 3.8 MB

# %% [markdown]
# ## Cleaning Poriton Description

# %%
def clean_portion_description(description):
    if not isinstance(description, str): return pd.NA
    description = description.lower()
    description = description.replace('quantity not specified', '')
    description = re.sub(r'guideline amount \w+', '', description)
    description = re.sub(r'^1 ', '', description)
    description = clean_ingredient_string(description)
    return description

food_portion_df['portion_cleaned'] = food_portion_df['portion_description'].apply(clean_portion_description)

# %%
food_portion_df
# Out:
#                 seq_num  amount  measure_unit_id     portion_description  \
# fdc_id  id
# 167516  81553         1     1.0             9999                    <NA>
#         81554         2     1.0             9999                    <NA>
# 167517  81555         1     1.0             9999                    <NA>
#         81556         2     1.0             9999                    <NA>
# 167518  81557         1     1.0             9999                    <NA>
# ...                 ...     ...              ...                     ...
# 2346354 290501        4    <NA>             9999  Quantity not specified
# 2346355 290502        3    <NA>             9999  Quantity not specified
#         290503        4    <NA>             9999        1 fl oz (no ice)
#         290504        5    <NA>             9999      1 fl oz (with ice)
#         290505        6    <NA>             9999           1 fl oz (NFS)
#
#                              modifier  gram_weight  data_points  footnote  \
# fdc_id  id
# 167516  81553          waffle, square         39.0           10      <NA>
#         81554           waffle, round         38.0           40      <NA>
# 167517  81555                      oz         28.0         <NA>      <NA>
#         81556   waffle round (4" dia)         33.0         <NA>      <NA>
# 167518  81557                  waffle         35.0         <NA>      <NA>
# ...                               ...          ...          ...       ...
# 2346354 290501                  90000        120.0         <NA>      <NA>
# 2346355 290502                  90000        248.0         <NA>      <NA>
#         290503                  30001         31.0         <NA>      <NA>
#         290504                  30009         23.0         <NA>      <NA>
#         290505                  30008         31.0         <NA>      <NA>
#
#                 min_year_acquired portion_cleaned
# fdc_id  id
# 167516  81553                <NA>             NaN
#         81554                <NA>             NaN
# 167517  81555                <NA>             NaN
#         81556                <NA>             NaN
# 167518  81557                <NA>             NaN
# ...                           ...             ...
# 2346354 290501               <NA>
# 2346355 290502               <NA>
#         290503               <NA>       fl oz ice
#         290504               <NA>       fl oz ice
#         290505               <NA>       fl oz nfs
#
# [22521 rows x 10 columns]

# %%
_ = food_portion_df[['portion_cleaned', 'portion_description']][food_portion_df['portion_cleaned'] != food_portion_df['portion_description']]
_[_['portion_description'].notnull()].head(20)
# Out:
#                             portion_cleaned  \
# fdc_id  id
# 2340760 267796                          cup
#         267797
#         267798                        fl oz
# 2340761 267799                          cup
#         267800                        fl oz
#         267801  individual school container
#         267802               fl oz beverage
#         267803               cup hot cereal
#         267804
# 2340762 267805                          cup
#         267806                        fl oz
#         267807  individual school container
#         267808               fl oz beverage
#         267809               cup hot cereal
#         267810
# 2340763 267811                          cup
#         267812                        fl oz
#         267813  individual school container
#         267814               fl oz beverage
#         267815               cup hot cereal
#
#                                    portion_description
# fdc_id  id
# 2340760 267796                                   1 cup
#         267797                  Quantity not specified
#         267798                                 1 fl oz
# 2340761 267799                                   1 cup
#         267800                                 1 fl oz
#         267801           1 individual school container
#         267802  Guideline amount per fl oz of beverage
#         267803  Guideline amount per cup of hot cereal
#         267804                  Quantity not specified
# 2340762 267805                                   1 cup
#         267806                                 1 fl oz
#         267807           1 individual school container
#         267808  Guideline amount per fl oz of beverage
#         267809  Guideline amount per cup of hot cereal
#         267810                  Quantity not specified
# 2340763 267811                                   1 cup
#         267812                                 1 fl oz
#         267813           1 individual school container
#         267814  Guideline amount per fl oz of beverage
#         267815  Guideline amount per cup of hot cereal

# %% [markdown]
# ## Selecting Portion Measures

# %% [markdown]
# This piece of data appears in various columns depending on the study mostly, but sometimes seemingly randomly. Here we want to gather all of this and select the appropriate one.

# %%
measure_unit_df = pd.read_csv('../data/datasets/density/FoodData_Central_csv_2023-04-20/measure_unit.csv', index_col='id')
measure_unit_df = measure_unit_df.convert_dtypes()
measure_unit_df['name'][measure_unit_df['name'] == 'undetermined'] = np.nan
measure_unit_df
# Out:
#              name
# id
# 1000          cup
# 1001   tablespoon
# 1002     teaspoon
# 1003        liter
# 1004   milliliter
# ...           ...
# 1117        bunch
# 1118  Tablespoons
# 1119       Banana
# 1120        Onion
# 9999         <NA>
#
# [122 rows x 1 columns]

# %%
food_portion_df.drop(columns=['measure_unit', 'description', 'combined', 'unit_tags', 'unit_remainders'], inplace=True, errors='ignore')

# %%
food_portion_df = food_portion_df.join(measure_unit_df.rename({'name':'measure_unit'}, axis=1), on='measure_unit_id')
food_portion_df
# Out:
#                 seq_num  amount  measure_unit_id     portion_description  \
# fdc_id  id
# 167516  81553         1     1.0             9999                    <NA>
#         81554         2     1.0             9999                    <NA>
# 167517  81555         1     1.0             9999                    <NA>
#         81556         2     1.0             9999                    <NA>
# 167518  81557         1     1.0             9999                    <NA>
# ...                 ...     ...              ...                     ...
# 2346354 290501        4    <NA>             9999  Quantity not specified
# 2346355 290502        3    <NA>             9999  Quantity not specified
#         290503        4    <NA>             9999        1 fl oz (no ice)
#         290504        5    <NA>             9999      1 fl oz (with ice)
#         290505        6    <NA>             9999           1 fl oz (NFS)
#
#                              modifier  gram_weight  data_points  footnote  \
# fdc_id  id
# 167516  81553          waffle, square         39.0           10      <NA>
#         81554           waffle, round         38.0           40      <NA>
# 167517  81555                      oz         28.0         <NA>      <NA>
#         81556   waffle round (4" dia)         33.0         <NA>      <NA>
# 167518  81557                  waffle         35.0         <NA>      <NA>
# ...                               ...          ...          ...       ...
# 2346354 290501                  90000        120.0         <NA>      <NA>
# 2346355 290502                  90000        248.0         <NA>      <NA>
#         290503                  30001         31.0         <NA>      <NA>
#         290504                  30009         23.0         <NA>      <NA>
#         290505                  30008         31.0         <NA>      <NA>
#
#                 min_year_acquired portion_cleaned measure_unit
# fdc_id  id
# 167516  81553                <NA>             NaN         <NA>
#         81554                <NA>             NaN         <NA>
# 167517  81555                <NA>             NaN         <NA>
#         81556                <NA>             NaN         <NA>
# 167518  81557                <NA>             NaN         <NA>
# ...                           ...             ...          ...
# 2346354 290501               <NA>                         <NA>
# 2346355 290502               <NA>                         <NA>
#         290503               <NA>       fl oz ice         <NA>
#         290504               <NA>       fl oz ice         <NA>
#         290505               <NA>       fl oz nfs         <NA>
#
# [22521 rows x 11 columns]

# %%
def combine_food_portion_description(portion):

    description = ''
    for col in ['measure_unit', 'portion_cleaned', 'modifier']:
        column_description = portion[col]
        if pd.isnull(column_description): continue
        if (col == 'modifier' and column_description.isnumeric()): continue
        description = description + " " + clean_portion_description(column_description)

    description = description.strip()

    return description

combined_description = food_portion_df.apply(combine_food_portion_description, axis=1).astype(str)
combined_description
# Out:
# fdc_id   id
# 167516   81553           waffle square
#          81554            waffle round
# 167517   81555                      oz
#          81556     waffle round 4 "dia
# 167518   81557                  waffle
#                           ...
# 2346354  290501
# 2346355  290502
#          290503              fl oz ice
#          290504              fl oz ice
#          290505              fl oz nfs
# Length: 22521, dtype: object

# %%
food_portion_df['combined_description'] = combined_description

# %%
food_portion_df
# Out:
#                 seq_num  amount  measure_unit_id     portion_description  \
# fdc_id  id
# 167516  81553         1     1.0             9999                    <NA>
#         81554         2     1.0             9999                    <NA>
# 167517  81555         1     1.0             9999                    <NA>
#         81556         2     1.0             9999                    <NA>
# 167518  81557         1     1.0             9999                    <NA>
# ...                 ...     ...              ...                     ...
# 2346354 290501        4    <NA>             9999  Quantity not specified
# 2346355 290502        3    <NA>             9999  Quantity not specified
#         290503        4    <NA>             9999        1 fl oz (no ice)
#         290504        5    <NA>             9999      1 fl oz (with ice)
#         290505        6    <NA>             9999           1 fl oz (NFS)
#
#                              modifier  gram_weight  data_points  footnote  \
# fdc_id  id
# 167516  81553          waffle, square         39.0           10      <NA>
#         81554           waffle, round         38.0           40      <NA>
# 167517  81555                      oz         28.0         <NA>      <NA>
#         81556   waffle round (4" dia)         33.0         <NA>      <NA>
# 167518  81557                  waffle         35.0         <NA>      <NA>
# ...                               ...          ...          ...       ...
# 2346354 290501                  90000        120.0         <NA>      <NA>
# 2346355 290502                  90000        248.0         <NA>      <NA>
#         290503                  30001         31.0         <NA>      <NA>
#         290504                  30009         23.0         <NA>      <NA>
#         290505                  30008         31.0         <NA>      <NA>
#
#                 min_year_acquired portion_cleaned measure_unit  \
# fdc_id  id
# 167516  81553                <NA>             NaN         <NA>
#         81554                <NA>             NaN         <NA>
# 167517  81555                <NA>             NaN         <NA>
#         81556                <NA>             NaN         <NA>
# 167518  81557                <NA>             NaN         <NA>
# ...                           ...             ...          ...
# 2346354 290501               <NA>                         <NA>
# 2346355 290502               <NA>                         <NA>
#         290503               <NA>       fl oz ice         <NA>
#         290504               <NA>       fl oz ice         <NA>
#         290505               <NA>       fl oz nfs         <NA>
#
#                combined_description
# fdc_id  id
# 167516  81553         waffle square
#         81554          waffle round
# 167517  81555                    oz
#         81556   waffle round 4 "dia
# 167518  81557                waffle
# ...                             ...
# 2346354 290501
# 2346355 290502
#         290503            fl oz ice
#         290504            fl oz ice
#         290505            fl oz nfs
#
# [22521 rows x 12 columns]

# %% [markdown]
# ## NA's

# %% [markdown]
# Here there will be food portions without any description. We want to remove these, but only for those foods which have portions with a description.

# %%
null_idxs = food_portion_df.index[food_portion_df['combined_description'] == ''].unique()
len(null_idxs)
# Out:
# 2769

# %%
non_null_food_idxs = food_portion_df.reset_index(1).index[food_portion_df['combined_description'] != ''].unique()
len(non_null_food_idxs)
# Out:
# 7455

# %%
null_idxs_with_alternatives = [idx for idx in null_idxs if idx[0] in non_null_food_idxs]
null_idxs_without_alternatives = [idx for idx in null_idxs if idx[0] not in non_null_food_idxs]

# %%
food_portion_df = food_portion_df[~food_portion_df.index.isin(null_idxs_with_alternatives)]

# %% [markdown]
# What about the ones without alternatives?

# %%
food_portion_df.loc[null_idxs_without_alternatives].join(food_df, on='fdc_id')
# Out:
#               seq_num  amount  measure_unit_id portion_description modifier  \
# fdc_id id
# 172079 89840        1     1.0             9999                <NA>     each
#
#               gram_weight  data_points  footnote  min_year_acquired  \
# fdc_id id
# 172079 89840         25.0            8      <NA>               <NA>
#
#              portion_cleaned  ... combined_description       data_type  \
# fdc_id id                     ...
# 172079 89840            <NA>  ...                       sr_legacy_food
#
#                                        description food_category_id  \
# fdc_id id
# 172079 89840  Fast foods, miniature cinnamon rolls             <NA>
#
#               publication_date                      description_list  \
# fdc_id id
# 172079 89840        2019-04-01  [fast food, miniature cinnamon roll]
#
#              description_length  description_list_length  default_word_count  \
# fdc_id id
# 172079 89840                 36                        2                   0
#
#               exclusion_word_count
# fdc_id id
# 172079 89840                     0
#
# [1 rows x 21 columns]

# %% [markdown]
# Just one obscure ingredient which can just be removed.

# %%
food_portion_df = food_portion_df[~food_portion_df.index.isin(null_idxs_without_alternatives)]

# %% [markdown]
# ## Syncing Food DF & Portion DF Entries

# %% [markdown]
# Only the foods with entries in the portion DF will be of use.

# %%
food_df = food_df[food_df.index.isin(food_portion_df.reset_index(1).index.unique())]

# %%
food_portion_df = food_portion_df[food_portion_df.index.get_level_values(0).isin(food_df.index.unique())]

# %% [markdown]
# ## Tagging Units

# %% [markdown]
# Just as we did in the previous chapter for the ingredients_df, we are tagging the units to allow them to be matched with eachother by homogenising them.

# %%
with open('../data/globals/unit_conversions.json') as f:
    unit_list = json.load(f)

# %%
unit_tags = parallel_apply(food_portion_df['combined_description'], tag_units, meta=pd.Series(dtype='object'))
unit_tags = unit_tags.apply(literal_eval)
food_portion_df['unit_tags'], food_portion_df['unit_remainders'], food_portion_df['unit_type'] = zip(*unit_tags)
# Out:
# [11/02/2024 11:25:37] [INFO] [food_database.utils.parallel] [parallel_apply():47] [PID:3853 TID:139957401994048] Commencing parallel apply
# [11/02/2024 11:25:37] [INFO] [food_database.utils.parallel] [parallel_apply():48] [PID:3853 TID:139957401994048] DF shape: (19752,) | DF size: 278.72 KB
# WARNING:bokeh.server.util:Host wildcard '*' will allow connections originating from multiple (or possibly all) hostnames or IPs. Use non-wildcard values to restrict access explicitly

# %%
food_portion_df[['combined_description', 'unit_tags', 'unit_remainders']]
# Out:
#                combined_description      unit_tags       unit_remainders
# fdc_id  id
# 167516  81553         waffle square             []      [waffle, square]
#         81554          waffle round             []       [waffle, round]
# 167517  81555                    oz        [ounce]                    []
#         81556   waffle round 4 "dia          [4.0]  [waffle, round, dia]
# 167518  81557                waffle             []              [waffle]
# ...                             ...            ...                   ...
# 2346354 290499                fl oz  [fluid_ounce]                    []
#         290500          bottle 4 oz   [4.0, ounce]              [bottle]
# 2346355 290503            fl oz ice  [fluid_ounce]                 [ice]
#         290504            fl oz ice  [fluid_ounce]                 [ice]
#         290505            fl oz nfs  [fluid_ounce]                 [nfs]
#
# [19752 rows x 3 columns]

# %%
food_portion_df[food_portion_df['unit_tags'].isnull()]
# Out:
# Empty DataFrame
# Columns: [seq_num, amount, measure_unit_id, portion_description, modifier, gram_weight, data_points, footnote, min_year_acquired, portion_cleaned, measure_unit, combined_description, unit_tags, unit_remainders, unit_type]
# Index: []

# %% [markdown]
# ### Portion Sizes

# %% [markdown]
# One additional piece of information would be useful here. When dealing with portions, sometimes their actual size is specified, or the amounts of them is specified. We want to be able to get this amount. It can be done with an additional tagging step of tagging the amounts?

# %%
food_portion_df.loc[332282.0]
# Out:
#         seq_num  amount  measure_unit_id portion_description modifier  \
# id
# 121416        1     1.0             1049                <NA>  1/2 cup
#
#         gram_weight  data_points  footnote  min_year_acquired portion_cleaned  \
# id
# 121416        135.0           36      <NA>               2009            <NA>
#
#        measure_unit combined_description            unit_tags unit_remainders  \
# id
# 121416      serving      serving 1/2 cup  [portion, 0.5, cup]              []
#
#        unit_type
# id
# 121416    volume

# %%
portion = food_portion_df.loc[(332282, 121416)]
portion
# Out:
# seq_num                                   1
# amount                                  1.0
# measure_unit_id                        1049
# portion_description                    <NA>
# modifier                            1/2 cup
# gram_weight                           135.0
# data_points                              36
# footnote                               <NA>
# min_year_acquired                      2009
# portion_cleaned                        <NA>
# measure_unit                        serving
# combined_description        serving 1/2 cup
# unit_tags               [portion, 0.5, cup]
# unit_remainders                          []
# unit_type                            volume
# Name: (332282, 121416), dtype: object

# %%
food_portion_df[food_portion_df['unit_tags'].apply(lambda x: any([i[0].isnumeric() for i in x]))].sample(20, random_state=777)
# Out:
#                 seq_num  amount  measure_unit_id  \
# fdc_id  id
# 2341553 271244        1    <NA>             9999
# 171847  89462         1     2.0             9999
# 173638  93003         1     1.0             9999
# 171966  89643         3     1.0             9999
# 2344182 282215        6    <NA>             9999
# 170028  85928         4     1.0             9999
# 169972  85786         2     1.0             9999
# 170849  87395         6     1.0             9999
# 171379  88595         6     1.0             9999
# 171284  88363         2     1.0             9999
# 173229  92149         1     1.0             9999
# 173653  93035         2     1.0             9999
# 170639  87010         2     1.0             9999
# 170636  87004         2     1.0             9999
# 174680  94743         1     1.0             9999
# 172415  90584         2     1.0             9999
# 170889  87508         5     1.0             9999
# 174613  94663         1    1.69             9999
# 171154  88081         2     1.0             9999
# 172829  91517         2     1.0             9999
#
#                                                                portion_description  \
# fdc_id  id
# 2341553 271244  1 hen (1-1/4 lb, raw) (yield after cooking, bone and skin removed)
# 171847  89462                                                                 <NA>
# 173638  93003                                                                 <NA>
# 171966  89643                                                                 <NA>
# 2344182 282215                               1 personal size pizza (5-7" diameter)
# 170028  85928                                                                 <NA>
# 169972  85786                                                                 <NA>
# 170849  87395                                                                 <NA>
# 171379  88595                                                                 <NA>
# 171284  88363                                                                 <NA>
# 173229  92149                                                                 <NA>
# 173653  93035                                                                 <NA>
# 170639  87010                                                                 <NA>
# 170636  87004                                                                 <NA>
# 174680  94743                                                                 <NA>
# 172415  90584                                                                 <NA>
# 170889  87508                                                                 <NA>
# 174613  94663                                                                 <NA>
# 171154  88081                                                                 <NA>
# 172829  91517                                                                 <NA>
#
#                                                                               modifier  \
# fdc_id  id
# 2341553 271244                                                                   60854
# 171847  89462                                                         cookie 1 serving
# 173638  93003                             unit (yield from 1 lb ready-to-cook chicken)
# 171966  89643                                                    can (6.5 oz), drained
# 2344182 282215                                                                   64363
# 170028  85928                                            small (1-3/4" to 2-1/4" dia.)
# 169972  85786                                                          package (10 oz)
# 170849  87395                                                           package (6 oz)
# 171379  88595                                             jar Beech-Nut Stage 2 (4 oz)
# 171284  88363                                                         container (8 oz)
# 173229  92149                                                  serving (3 heaping tsp)
# 173653  93035                                                           can (12 fl oz)
# 170639  87010   piece, cooked, excluding refuse (yield from 1 lb raw meat with refuse)
# 170636  87004                                       roast (yield from 1405 g raw meat)
# 174680  94743                                                            can (6 fl oz)
# 172415  90584                               unit (yield from 1 lb ready-to-cook goose)
# 170889  87508                                                         container (8 oz)
# 174613  94663                                                           oz (1 serving)
# 171154  88081                                                           can (10.75 oz)
# 172829  91517                               unit (yield from 1 lb ready-to cook quail)
#
#                 gram_weight  data_points  footnote  min_year_acquired  \
# fdc_id  id
# 2341553 271244        250.0         <NA>      <NA>               <NA>
# 171847  89462          36.0         <NA>      <NA>               <NA>
# 173638  93003         113.0         <NA>      <NA>               <NA>
# 171966  89643         125.0         <NA>      <NA>               <NA>
# 2344182 282215        240.0         <NA>      <NA>               <NA>
# 170028  85928          92.0         <NA>      <NA>               <NA>
# 169972  85786         284.0         <NA>      <NA>               <NA>
# 170849  87395         170.0         <NA>      <NA>               <NA>
# 171379  88595         113.0         <NA>      <NA>               <NA>
# 171284  88363         227.0         <NA>      <NA>               <NA>
# 173229  92149          23.0         <NA>      <NA>               <NA>
# 173653  93035         435.0         <NA>      <NA>               <NA>
# 170639  87010         267.0         <NA>      <NA>               <NA>
# 170636  87004        1138.0           10      <NA>               <NA>
# 174680  94743         207.0         <NA>      <NA>               <NA>
# 172415  90584          11.0         <NA>      <NA>               <NA>
# 170889  87508         227.0         <NA>      <NA>               <NA>
# 174613  94663          48.0            1      <NA>               <NA>
# 171154  88081         305.0         <NA>      <NA>               <NA>
# 172829  91517         208.0         <NA>      <NA>               <NA>
#
#                                                  portion_cleaned measure_unit  \
# fdc_id  id
# 2341553 271244  hen 1-1/4 lb raw yield cooking bone skin removed         <NA>
# 171847  89462                                               <NA>         <NA>
# 173638  93003                                               <NA>         <NA>
# 171966  89643                                               <NA>         <NA>
# 2344182 282215                 personal size pizza 5-7 "diameter         <NA>
# 170028  85928                                               <NA>         <NA>
# 169972  85786                                               <NA>         <NA>
# 170849  87395                                               <NA>         <NA>
# 171379  88595                                               <NA>         <NA>
# 171284  88363                                               <NA>         <NA>
# 173229  92149                                               <NA>         <NA>
# 173653  93035                                               <NA>         <NA>
# 170639  87010                                               <NA>         <NA>
# 170636  87004                                               <NA>         <NA>
# 174680  94743                                               <NA>         <NA>
# 172415  90584                                               <NA>         <NA>
# 170889  87508                                               <NA>         <NA>
# 174613  94663                                               <NA>         <NA>
# 171154  88081                                               <NA>         <NA>
# 172829  91517                                               <NA>         <NA>
#
#                                                     combined_description  \
# fdc_id  id
# 2341553 271244          hen 1-1/4 lb raw yield cooking bone skin removed
# 171847  89462                                           cookie 1 serving
# 173638  93003                      unit yield 1 lb ready-to-cook chicken
# 171966  89643                                          can 65 oz drained
# 2344182 282215                         personal size pizza 5-7 "diameter
# 170028  85928                                    small 1-3/4 "2-1/4" dia
# 169972  85786                                              package 10 oz
# 170849  87395                                               package 6 oz
# 171379  88595                                 jar beech-nut stage 2 4 oz
# 171284  88363                                             container 8 oz
# 173229  92149                                      serving 3 heaping tsp
# 173653  93035                                               can 12 fl oz
# 170639  87010   piece cooked excluding refuse yield 1 lb raw meat refuse
# 170636  87004                                roast yield 1405 g raw meat
# 174680  94743                                                can 6 fl oz
# 172415  90584                        unit yield 1 lb ready-to-cook goose
# 170889  87508                                             container 8 oz
# 174613  94663                                               oz 1 serving
# 171154  88081                                                can 1075 oz
# 172829  91517                        unit yield 1 lb ready-to cook quail
#
#                                    unit_tags  \
# fdc_id  id
# 2341553 271244            [1.0, 0.25, pound]
# 171847  89462                 [1.0, portion]
# 173638  93003                   [1.0, pound]
# 171966  89643             [can, 65.0, ounce]
# 2344182 282215                    [5.0, 7.0]
# 170028  85928   [whole, 1.0, 3.0, 2.0, 0.25]
# 169972  85786         [package, 10.0, ounce]
# 170849  87395          [package, 6.0, ounce]
# 171379  88595            [whole, 6.0, ounce]
# 171284  88363                   [8.0, ounce]
# 173229  92149       [portion, 3.0, teaspoon]
# 173653  93035       [can, 12.0, fluid_ounce]
# 170639  87010            [piece, 1.0, pound]
# 170636  87004                 [1405.0, gram]
# 174680  94743        [can, 6.0, fluid_ounce]
# 172415  90584                   [1.0, pound]
# 170889  87508                   [8.0, ounce]
# 174613  94663          [ounce, 1.0, portion]
# 171154  88081           [can, 1075.0, ounce]
# 172829  91517                   [1.0, pound]
#
#                                                       unit_remainders  \
# fdc_id  id
# 2341553 271244        [hen, raw, yield, cooking, bone, skin, removed]
# 171847  89462                                                [cookie]
# 173638  93003                 [unit, yield, ready, to, cook, chicken]
# 171966  89643                                               [drained]
# 2344182 282215                      [personal, size, pizza, diameter]
# 170028  85928                                                   [dia]
# 169972  85786                                                      []
# 170849  87395                                                      []
# 171379  88595                                     [jar, beech, stage]
# 171284  88363                                             [container]
# 173229  92149                                               [heaping]
# 173653  93035                                                      []
# 170639  87010   [cooked, excluding, refuse, yield, raw, meat, refuse]
# 170636  87004                               [roast, yield, raw, meat]
# 174680  94743                                                      []
# 172415  90584                   [unit, yield, ready, to, cook, goose]
# 170889  87508                                             [container]
# 174613  94663                                                      []
# 171154  88081                                                      []
# 172829  91517                   [unit, yield, ready, to, cook, quail]
#
#                unit_type
# fdc_id  id
# 2341553 271244    weight
# 171847  89462    portion
# 173638  93003     weight
# 171966  89643     volume
# 2344182 282215   portion
# 170028  85928    portion
# 169972  85786     weight
# 170849  87395     weight
# 171379  88595     weight
# 171284  88363     weight
# 173229  92149     volume
# 173653  93035     volume
# 170639  87010     weight
# 170636  87004     weight
# 174680  94743     volume
# 172415  90584     weight
# 170889  87508     weight
# 174613  94663     weight
# 171154  88081     volume
# 172829  91517     weight

# %%
def get_portion_measure(portion_unit_tags):
    modifier = (pd.NA, pd.NA)
    for i, unit_tag in enumerate(portion_unit_tags):
        if i == len(portion_unit_tags)-1: continue
        if unit_tag[0].isnumeric() and portion_unit_tags[i+1] in [*unit_list['weight'].keys(), *unit_list['volume'].keys(), *unit_list['portion'].keys()]:
            modifier = (float(unit_tag), portion_unit_tags[i+1])
    return modifier

assert get_portion_measure(portion['unit_tags']) == (0.5, 'cup')

# %%
food_portion_df['portion_amount'], food_portion_df['portion_unit'] = zip(*food_portion_df['unit_tags'].apply(get_portion_measure))

# %%
food_portion_df[food_portion_df['unit_tags'].apply(lambda x: any([i[0].isnumeric() for i in x]))].sample(20, random_state=777)
# Out:
#                 seq_num  amount  measure_unit_id  \
# fdc_id  id
# 2341553 271244        1    <NA>             9999
# 171847  89462         1     2.0             9999
# 173638  93003         1     1.0             9999
# 171966  89643         3     1.0             9999
# 2344182 282215        6    <NA>             9999
# 170028  85928         4     1.0             9999
# 169972  85786         2     1.0             9999
# 170849  87395         6     1.0             9999
# 171379  88595         6     1.0             9999
# 171284  88363         2     1.0             9999
# 173229  92149         1     1.0             9999
# 173653  93035         2     1.0             9999
# 170639  87010         2     1.0             9999
# 170636  87004         2     1.0             9999
# 174680  94743         1     1.0             9999
# 172415  90584         2     1.0             9999
# 170889  87508         5     1.0             9999
# 174613  94663         1    1.69             9999
# 171154  88081         2     1.0             9999
# 172829  91517         2     1.0             9999
#
#                                                                portion_description  \
# fdc_id  id
# 2341553 271244  1 hen (1-1/4 lb, raw) (yield after cooking, bone and skin removed)
# 171847  89462                                                                 <NA>
# 173638  93003                                                                 <NA>
# 171966  89643                                                                 <NA>
# 2344182 282215                               1 personal size pizza (5-7" diameter)
# 170028  85928                                                                 <NA>
# 169972  85786                                                                 <NA>
# 170849  87395                                                                 <NA>
# 171379  88595                                                                 <NA>
# 171284  88363                                                                 <NA>
# 173229  92149                                                                 <NA>
# 173653  93035                                                                 <NA>
# 170639  87010                                                                 <NA>
# 170636  87004                                                                 <NA>
# 174680  94743                                                                 <NA>
# 172415  90584                                                                 <NA>
# 170889  87508                                                                 <NA>
# 174613  94663                                                                 <NA>
# 171154  88081                                                                 <NA>
# 172829  91517                                                                 <NA>
#
#                                                                               modifier  \
# fdc_id  id
# 2341553 271244                                                                   60854
# 171847  89462                                                         cookie 1 serving
# 173638  93003                             unit (yield from 1 lb ready-to-cook chicken)
# 171966  89643                                                    can (6.5 oz), drained
# 2344182 282215                                                                   64363
# 170028  85928                                            small (1-3/4" to 2-1/4" dia.)
# 169972  85786                                                          package (10 oz)
# 170849  87395                                                           package (6 oz)
# 171379  88595                                             jar Beech-Nut Stage 2 (4 oz)
# 171284  88363                                                         container (8 oz)
# 173229  92149                                                  serving (3 heaping tsp)
# 173653  93035                                                           can (12 fl oz)
# 170639  87010   piece, cooked, excluding refuse (yield from 1 lb raw meat with refuse)
# 170636  87004                                       roast (yield from 1405 g raw meat)
# 174680  94743                                                            can (6 fl oz)
# 172415  90584                               unit (yield from 1 lb ready-to-cook goose)
# 170889  87508                                                         container (8 oz)
# 174613  94663                                                           oz (1 serving)
# 171154  88081                                                           can (10.75 oz)
# 172829  91517                               unit (yield from 1 lb ready-to cook quail)
#
#                 gram_weight  data_points  footnote  min_year_acquired  \
# fdc_id  id
# 2341553 271244        250.0         <NA>      <NA>               <NA>
# 171847  89462          36.0         <NA>      <NA>               <NA>
# 173638  93003         113.0         <NA>      <NA>               <NA>
# 171966  89643         125.0         <NA>      <NA>               <NA>
# 2344182 282215        240.0         <NA>      <NA>               <NA>
# 170028  85928          92.0         <NA>      <NA>               <NA>
# 169972  85786         284.0         <NA>      <NA>               <NA>
# 170849  87395         170.0         <NA>      <NA>               <NA>
# 171379  88595         113.0         <NA>      <NA>               <NA>
# 171284  88363         227.0         <NA>      <NA>               <NA>
# 173229  92149          23.0         <NA>      <NA>               <NA>
# 173653  93035         435.0         <NA>      <NA>               <NA>
# 170639  87010         267.0         <NA>      <NA>               <NA>
# 170636  87004        1138.0           10      <NA>               <NA>
# 174680  94743         207.0         <NA>      <NA>               <NA>
# 172415  90584          11.0         <NA>      <NA>               <NA>
# 170889  87508         227.0         <NA>      <NA>               <NA>
# 174613  94663          48.0            1      <NA>               <NA>
# 171154  88081         305.0         <NA>      <NA>               <NA>
# 172829  91517         208.0         <NA>      <NA>               <NA>
#
#                                                  portion_cleaned measure_unit  \
# fdc_id  id
# 2341553 271244  hen 1-1/4 lb raw yield cooking bone skin removed         <NA>
# 171847  89462                                               <NA>         <NA>
# 173638  93003                                               <NA>         <NA>
# 171966  89643                                               <NA>         <NA>
# 2344182 282215                 personal size pizza 5-7 "diameter         <NA>
# 170028  85928                                               <NA>         <NA>
# 169972  85786                                               <NA>         <NA>
# 170849  87395                                               <NA>         <NA>
# 171379  88595                                               <NA>         <NA>
# 171284  88363                                               <NA>         <NA>
# 173229  92149                                               <NA>         <NA>
# 173653  93035                                               <NA>         <NA>
# 170639  87010                                               <NA>         <NA>
# 170636  87004                                               <NA>         <NA>
# 174680  94743                                               <NA>         <NA>
# 172415  90584                                               <NA>         <NA>
# 170889  87508                                               <NA>         <NA>
# 174613  94663                                               <NA>         <NA>
# 171154  88081                                               <NA>         <NA>
# 172829  91517                                               <NA>         <NA>
#
#                                                     combined_description  \
# fdc_id  id
# 2341553 271244          hen 1-1/4 lb raw yield cooking bone skin removed
# 171847  89462                                           cookie 1 serving
# 173638  93003                      unit yield 1 lb ready-to-cook chicken
# 171966  89643                                          can 65 oz drained
# 2344182 282215                         personal size pizza 5-7 "diameter
# 170028  85928                                    small 1-3/4 "2-1/4" dia
# 169972  85786                                              package 10 oz
# 170849  87395                                               package 6 oz
# 171379  88595                                 jar beech-nut stage 2 4 oz
# 171284  88363                                             container 8 oz
# 173229  92149                                      serving 3 heaping tsp
# 173653  93035                                               can 12 fl oz
# 170639  87010   piece cooked excluding refuse yield 1 lb raw meat refuse
# 170636  87004                                roast yield 1405 g raw meat
# 174680  94743                                                can 6 fl oz
# 172415  90584                        unit yield 1 lb ready-to-cook goose
# 170889  87508                                             container 8 oz
# 174613  94663                                               oz 1 serving
# 171154  88081                                                can 1075 oz
# 172829  91517                        unit yield 1 lb ready-to cook quail
#
#                                    unit_tags  \
# fdc_id  id
# 2341553 271244            [1.0, 0.25, pound]
# 171847  89462                 [1.0, portion]
# 173638  93003                   [1.0, pound]
# 171966  89643             [can, 65.0, ounce]
# 2344182 282215                    [5.0, 7.0]
# 170028  85928   [whole, 1.0, 3.0, 2.0, 0.25]
# 169972  85786         [package, 10.0, ounce]
# 170849  87395          [package, 6.0, ounce]
# 171379  88595            [whole, 6.0, ounce]
# 171284  88363                   [8.0, ounce]
# 173229  92149       [portion, 3.0, teaspoon]
# 173653  93035       [can, 12.0, fluid_ounce]
# 170639  87010            [piece, 1.0, pound]
# 170636  87004                 [1405.0, gram]
# 174680  94743        [can, 6.0, fluid_ounce]
# 172415  90584                   [1.0, pound]
# 170889  87508                   [8.0, ounce]
# 174613  94663          [ounce, 1.0, portion]
# 171154  88081           [can, 1075.0, ounce]
# 172829  91517                   [1.0, pound]
#
#                                                       unit_remainders  \
# fdc_id  id
# 2341553 271244        [hen, raw, yield, cooking, bone, skin, removed]
# 171847  89462                                                [cookie]
# 173638  93003                 [unit, yield, ready, to, cook, chicken]
# 171966  89643                                               [drained]
# 2344182 282215                      [personal, size, pizza, diameter]
# 170028  85928                                                   [dia]
# 169972  85786                                                      []
# 170849  87395                                                      []
# 171379  88595                                     [jar, beech, stage]
# 171284  88363                                             [container]
# 173229  92149                                               [heaping]
# 173653  93035                                                      []
# 170639  87010   [cooked, excluding, refuse, yield, raw, meat, refuse]
# 170636  87004                               [roast, yield, raw, meat]
# 174680  94743                                                      []
# 172415  90584                   [unit, yield, ready, to, cook, goose]
# 170889  87508                                             [container]
# 174613  94663                                                      []
# 171154  88081                                                      []
# 172829  91517                   [unit, yield, ready, to, cook, quail]
#
#                unit_type portion_amount portion_unit
# fdc_id  id
# 2341553 271244    weight           0.25        pound
# 171847  89462    portion            1.0      portion
# 173638  93003     weight            1.0        pound
# 171966  89643     volume           65.0        ounce
# 2344182 282215   portion           <NA>         <NA>
# 170028  85928    portion           <NA>         <NA>
# 169972  85786     weight           10.0        ounce
# 170849  87395     weight            6.0        ounce
# 171379  88595     weight            6.0        ounce
# 171284  88363     weight            8.0        ounce
# 173229  92149     volume            3.0     teaspoon
# 173653  93035     volume           12.0  fluid_ounce
# 170639  87010     weight            1.0        pound
# 170636  87004     weight         1405.0         gram
# 174680  94743     volume            6.0  fluid_ounce
# 172415  90584     weight            1.0        pound
# 170889  87508     weight            8.0        ounce
# 174613  94663     weight            1.0      portion
# 171154  88081     volume         1075.0        ounce
# 172829  91517     weight            1.0        pound

# %%
food_portion_df['amount'].fillna(1.0, inplace=True)

# %% [markdown]
# ## Removing Weight Values

# %% [markdown]
# The portions containing a weight value are completely useless. weight -> gram_weight. Let's remove these.

# %%
def filter_weight(portion):
    if not len(portion['unit_remainders']) > 0:
        if len(portion['unit_tags']) > 0:
            if all([unit in unit_list['weight'].keys() for unit in portion['unit_tags']]):
                return False
    return True

filtered = food_portion_df[food_portion_df.apply(filter_weight, axis=1)]
food_portion_df = pd.concat([filtered, food_portion_df[~food_portion_df.reset_index(1).index.isin(filtered.reset_index(1).index.unique())]]) # add back those where all portions for the fdc_id were removed

# %% [markdown]
# ## Highlighting Density Entries

# %% [markdown]
# Keeping in mind that the purpose of this dataset being to calculate densities, we hould know that they only useful portions here are ones containing volume entries. However we don't quite want to remove those which don't contain volume, as they might be useful (to determine portion weights). Why don't we instead make a Boolean field in the food_df `density_exists`.

# %%
food_df.loc[171474]
# Out:
# data_type                                                           sr_legacy_food
# description                Chicken, broilers or fryers, breast, meat and skin, raw
# food_category_id                                                              <NA>
# publication_date                                                        2019-04-01
# description_list                  [chicken, broiler fryer, breast, meat skin, raw]
# description_length                                                              55
# description_list_length                                                          5
# default_word_count                                                               1
# exclusion_word_count                                                             0
# Name: 171474, dtype: object

# %%
def check_portion_type(food):
    volume, portion = False, False
    portions = food_portion_df.loc[food.name]
    if any([any([portion_unit in unit_list['volume'].keys() for portion_unit in portion]) for portion in portions['unit_tags']]):
        volume = True
    if any([any([portion_unit in unit_list['portion'].keys() for portion_unit in portion]) for portion in portions['unit_tags']]):
        portion = True

    return volume, portion

check_portion_type(food_df.iloc[0])
# Out:
# (False, False)

# %%
food_df['volume_exists'], food_df['portion_exists'] = zip(*food_df.apply(check_portion_type, axis=1))

# %% [markdown]
# ## Filtering Non-Density Foods

# %%
food_df.shape
# Out:
# (7455, 11)

# %%
food_df = food_df[~(~food_df['volume_exists'] & ~food_df['portion_exists'])]
food_df.shape
# Out:
# (5302, 11)

# %% [markdown]
# ## Column Selection

# %%
food_df
# Out:
#                  data_type  \
# fdc_id
# 167525      sr_legacy_food
# 167526      sr_legacy_food
# 167527      sr_legacy_food
# 167528      sr_legacy_food
# 167532      sr_legacy_food
# ...                    ...
# 2346349  survey_fndds_food
# 2346352  survey_fndds_food
# 2346353  survey_fndds_food
# 2346354  survey_fndds_food
# 2346355  survey_fndds_food
#
#                                                      description  \
# fdc_id
# 167525                                      Tostada shells, corn
# 167526   Bread, salvadoran sweet cheese (quesadilla salvadorena)
# 167527           Bread, pound cake type, pan de torta salvadoran
# 167528              Pastry, Pastelitos de Guava (guava pastries)
# 167532                                        Bread, white wheat
# ...                                                          ...
# 2346349                                        Sports drink, NFS
# 2346352                                Sports drink, low calorie
# 2346353                  Fluid replacement, electrolyte solution
# 2346354                   Fluid replacement, 5% glucose in water
# 2346355                                  Fruit juice, acai blend
#
#          food_category_id publication_date  \
# fdc_id
# 167525               <NA>       2019-04-01
# 167526               <NA>       2019-04-01
# 167527               <NA>       2019-04-01
# 167528               <NA>       2019-04-01
# 167532               <NA>       2019-04-01
# ...                   ...              ...
# 2346349              7206       2022-10-28
# 2346352              7104       2022-10-28
# 2346353              7206       2022-10-28
# 2346354              7206       2022-10-28
# 2346355              7204       2022-10-28
#
#                                                 description_list  \
# fdc_id
# 167525                                     [tostada shell, corn]
# 167526   [bread, salvadoran sweet cheese quesadilla salvadorena]
# 167527         [bread, pound cake type, pan de torta salvadoran]
# 167528                [pastry, pastelitos de guava guava pastry]
# 167532                                      [bread, white wheat]
# ...                                                          ...
# 2346349                                       [sport drink, nfs]
# 2346352                               [sport drink, low calorie]
# 2346353                [fluid replacement, electrolyte solution]
# 2346354                    [fluid replacement, 5% glucose water]
# 2346355                                [fruit juice, acai blend]
#
#          description_length  description_list_length  default_word_count  \
# fdc_id
# 167525                   20                        2                   0
# 167526                   55                        2                   0
# 167527                   47                        3                   0
# 167528                   44                        2                   0
# 167532                   18                        2                   0
# ...                     ...                      ...                 ...
# 2346349                  17                        2                   1
# 2346352                  25                        2                   0
# 2346353                  39                        2                   0
# 2346354                  38                        2                   0
# 2346355                  23                        2                   0
#
#          exclusion_word_count  volume_exists  portion_exists
# fdc_id
# 167525                      0          False            True
# 167526                      0          False            True
# 167527                      0          False            True
# 167528                      0          False            True
# 167532                      0          False            True
# ...                       ...            ...             ...
# 2346349                     0           True           False
# 2346352                     1           True           False
# 2346353                     0           True           False
# 2346354                     0           True           False
# 2346355                     0           True           False
#
# [5302 rows x 11 columns]

# %%
food_df.drop(['food_category_id', 'publication_date'], axis=1, inplace=True)

# %% [markdown]
# There's a lot of unnecessary data here, let's filter out only that which we need.

# %%
food_portion_df
# Out:
#                 seq_num  amount  measure_unit_id portion_description  \
# fdc_id  id
# 167516  81553         1     1.0             9999                <NA>
#         81554         2     1.0             9999                <NA>
# 167517  81556         2     1.0             9999                <NA>
# 167518  81557         1     1.0             9999                <NA>
# 167519  81558         1     1.0             9999                <NA>
# ...                 ...     ...              ...                 ...
# 175303  95995         2     1.0             9999                <NA>
# 323604  119060        1     1.0             1038                <NA>
# 323697  119063        1     1.0             1038                <NA>
# 329596  119694        1     1.0             1038                <NA>
# 2342923 275755        1     1.0             9999                1 oz
#
#                              modifier  gram_weight  data_points  footnote  \
# fdc_id  id
# 167516  81553          waffle, square         39.0           10      <NA>
#         81554           waffle, round         38.0           40      <NA>
# 167517  81556   waffle round (4" dia)         33.0         <NA>      <NA>
# 167518  81557                  waffle         35.0         <NA>      <NA>
# 167519  81558   waffle, round (4"dia)         32.0         <NA>      <NA>
# ...                               ...          ...          ...       ...
# 175303  95995                      lb        453.6         <NA>      <NA>
# 323604  119060                   <NA>         28.4            1      <NA>
# 323697  119063                   <NA>         28.4            1      <NA>
# 329596  119694                   <NA>         28.4            1      <NA>
# 2342923 275755                  40000        28.35         <NA>      <NA>
#
#                 min_year_acquired portion_cleaned measure_unit  \
# fdc_id  id
# 167516  81553                <NA>             NaN         <NA>
#         81554                <NA>             NaN         <NA>
# 167517  81556                <NA>             NaN         <NA>
# 167518  81557                <NA>             NaN         <NA>
# 167519  81558                <NA>             NaN         <NA>
# ...                           ...             ...          ...
# 175303  95995                <NA>            <NA>         <NA>
# 323604  119060               2017            <NA>           oz
# 323697  119063               2017            <NA>           oz
# 329596  119694               2017            <NA>           oz
# 2342923 275755               <NA>              oz         <NA>
#
#                combined_description unit_tags       unit_remainders unit_type  \
# fdc_id  id
# 167516  81553         waffle square        []      [waffle, square]   portion
#         81554          waffle round        []       [waffle, round]   portion
# 167517  81556   waffle round 4 "dia     [4.0]  [waffle, round, dia]   portion
# 167518  81557                waffle        []              [waffle]   portion
# 167519  81558   waffle round 4 "dia     [4.0]  [waffle, round, dia]   portion
# ...                             ...       ...                   ...       ...
# 175303  95995                    lb   [pound]                    []    weight
# 323604  119060                   oz   [ounce]                    []    weight
# 323697  119063                   oz   [ounce]                    []    weight
# 329596  119694                   oz   [ounce]                    []    weight
# 2342923 275755                   oz   [ounce]                    []    weight
#
#                portion_amount portion_unit
# fdc_id  id
# 167516  81553             NaN          NaN
#         81554             NaN          NaN
# 167517  81556             NaN          NaN
# 167518  81557             NaN          NaN
# 167519  81558             NaN          NaN
# ...                       ...          ...
# 175303  95995             NaN          NaN
# 323604  119060            NaN          NaN
# 323697  119063            NaN          NaN
# 329596  119694            NaN          NaN
# 2342923 275755            NaN          NaN
#
# [17885 rows x 17 columns]

# %%
food_portion_df.drop(columns=['measure_unit_id','portion_description','modifier','data_points','footnote','min_year_acquired','measure_unit', 'portion_cleaned'],inplace=True)
food_portion_df.rename(columns={'combined_description': 'description'}, inplace=True)

# %%
food_portion_df
# Out:
#                 seq_num  amount  gram_weight          description unit_tags  \
# fdc_id  id
# 167516  81553         1     1.0         39.0        waffle square        []
#         81554         2     1.0         38.0         waffle round        []
# 167517  81556         2     1.0         33.0  waffle round 4 "dia     [4.0]
# 167518  81557         1     1.0         35.0               waffle        []
# 167519  81558         1     1.0         32.0  waffle round 4 "dia     [4.0]
# ...                 ...     ...          ...                  ...       ...
# 175303  95995         2     1.0        453.6                   lb   [pound]
# 323604  119060        1     1.0         28.4                   oz   [ounce]
# 323697  119063        1     1.0         28.4                   oz   [ounce]
# 329596  119694        1     1.0         28.4                   oz   [ounce]
# 2342923 275755        1     1.0        28.35                   oz   [ounce]
#
#                      unit_remainders unit_type portion_amount portion_unit
# fdc_id  id
# 167516  81553       [waffle, square]   portion            NaN          NaN
#         81554        [waffle, round]   portion            NaN          NaN
# 167517  81556   [waffle, round, dia]   portion            NaN          NaN
# 167518  81557               [waffle]   portion            NaN          NaN
# 167519  81558   [waffle, round, dia]   portion            NaN          NaN
# ...                              ...       ...            ...          ...
# 175303  95995                     []    weight            NaN          NaN
# 323604  119060                    []    weight            NaN          NaN
# 323697  119063                    []    weight            NaN          NaN
# 329596  119694                    []    weight            NaN          NaN
# 2342923 275755                    []    weight            NaN          NaN
#
# [17885 rows x 9 columns]

# %% [markdown]
# ## Syncing Food DF & Portion DF Entries

# %% [markdown]
# Only the foods with entries in the portion DF will be of use.

# %%
food_df = food_df[food_df.index.isin(food_portion_df.reset_index(1).index.unique())]

# %%
food_portion_df = food_portion_df[food_portion_df.index.get_level_values(0).isin(food_df.index.unique())]

# %% [markdown]
# # Saving

# %%
food_df
# Out:
#                  data_type  \
# fdc_id
# 167525      sr_legacy_food
# 167526      sr_legacy_food
# 167527      sr_legacy_food
# 167528      sr_legacy_food
# 167532      sr_legacy_food
# ...                    ...
# 2346349  survey_fndds_food
# 2346352  survey_fndds_food
# 2346353  survey_fndds_food
# 2346354  survey_fndds_food
# 2346355  survey_fndds_food
#
#                                                      description  \
# fdc_id
# 167525                                      Tostada shells, corn
# 167526   Bread, salvadoran sweet cheese (quesadilla salvadorena)
# 167527           Bread, pound cake type, pan de torta salvadoran
# 167528              Pastry, Pastelitos de Guava (guava pastries)
# 167532                                        Bread, white wheat
# ...                                                          ...
# 2346349                                        Sports drink, NFS
# 2346352                                Sports drink, low calorie
# 2346353                  Fluid replacement, electrolyte solution
# 2346354                   Fluid replacement, 5% glucose in water
# 2346355                                  Fruit juice, acai blend
#
#                                                 description_list  \
# fdc_id
# 167525                                     [tostada shell, corn]
# 167526   [bread, salvadoran sweet cheese quesadilla salvadorena]
# 167527         [bread, pound cake type, pan de torta salvadoran]
# 167528                [pastry, pastelitos de guava guava pastry]
# 167532                                      [bread, white wheat]
# ...                                                          ...
# 2346349                                       [sport drink, nfs]
# 2346352                               [sport drink, low calorie]
# 2346353                [fluid replacement, electrolyte solution]
# 2346354                    [fluid replacement, 5% glucose water]
# 2346355                                [fruit juice, acai blend]
#
#          description_length  description_list_length  default_word_count  \
# fdc_id
# 167525                   20                        2                   0
# 167526                   55                        2                   0
# 167527                   47                        3                   0
# 167528                   44                        2                   0
# 167532                   18                        2                   0
# ...                     ...                      ...                 ...
# 2346349                  17                        2                   1
# 2346352                  25                        2                   0
# 2346353                  39                        2                   0
# 2346354                  38                        2                   0
# 2346355                  23                        2                   0
#
#          exclusion_word_count  volume_exists  portion_exists
# fdc_id
# 167525                      0          False            True
# 167526                      0          False            True
# 167527                      0          False            True
# 167528                      0          False            True
# 167532                      0          False            True
# ...                       ...            ...             ...
# 2346349                     0           True           False
# 2346352                     1           True           False
# 2346353                     0           True           False
# 2346354                     0           True           False
# 2346355                     0           True           False
#
# [5302 rows x 9 columns]

# %%
food_portion_df
# Out:
#                 seq_num  amount  gram_weight  \
# fdc_id  id
# 167525  81568         1     1.0         12.3
#         81569         2     3.0         37.0
# 167526  81570         1     1.0         55.0
#         81571         2     1.0        399.0
# 167527  81572         1     1.0         55.0
# ...                 ...     ...          ...
# 2346354 290499        2     1.0         30.0
#         290500        3     1.0        120.0
# 2346355 290503        4     1.0         31.0
#         290504        5     1.0         23.0
#         290505        6     1.0         31.0
#
#                                                description  \
# fdc_id  id
# 167525  81568                                        piece
#         81569   piece mean serving weight aggregated brand
# 167526  81570             serving approximate serving size
#         81571        cake square average weight whole item
# 167527  81572                                      serving
# ...                                                    ...
# 2346354 290499                                       fl oz
#         290500                                 bottle 4 oz
# 2346355 290503                                   fl oz ice
#         290504                                   fl oz ice
#         290505                                   fl oz nfs
#
#                          unit_tags                        unit_remainders  \
# fdc_id  id
# 167525  81568              [piece]                                     []
#         81569     [piece, portion]      [mean, weight, aggregated, brand]
# 167526  81570   [portion, portion]                    [approximate, size]
#         81571              [whole]  [cake, square, average, weight, item]
# 167527  81572            [portion]                                     []
# ...                            ...                                    ...
# 2346354 290499       [fluid_ounce]                                     []
#         290500        [4.0, ounce]                               [bottle]
# 2346355 290503       [fluid_ounce]                                  [ice]
#         290504       [fluid_ounce]                                  [ice]
#         290505       [fluid_ounce]                                  [nfs]
#
#                unit_type portion_amount portion_unit
# fdc_id  id
# 167525  81568    portion            NaN          NaN
#         81569    portion            NaN          NaN
# 167526  81570    portion            NaN          NaN
#         81571    portion            NaN          NaN
# 167527  81572    portion            NaN          NaN
# ...                  ...            ...          ...
# 2346354 290499    volume           <NA>         <NA>
#         290500    weight            4.0        ounce
# 2346355 290503    volume           <NA>         <NA>
#         290504    volume           <NA>         <NA>
#         290505    volume           <NA>         <NA>
#
# [15080 rows x 9 columns]

# %%
food_df.to_feather('../data/local/density/full/food/0.feather')
food_portion_df.to_feather('../data/local/density/full/food_portion/0.feather')
